# %% [raw]
# print(hello)

# %%
print("hello")
# Out:
# hello

# %%
hello
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 hello
#
# NameError: name 'hello' is not defined

# %%
integer=123
print(integer)
# Out:
# 123
